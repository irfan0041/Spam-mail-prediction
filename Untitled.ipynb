# %% [markdown]
# ## Importing the Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
raw_mail_data = pd.read_csv('mail_data.csv')

# %%
print(raw_mail_data)
# Out:
#      Category                                            Message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...
# 5568      ham               Will ü b going to esplanade fr home?
# 5569      ham  Pity, * was in mood for that. So...any other s...
# 5570      ham  The guy did some bitching but I acted like i'd...
# 5571      ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
mail_data = raw_mail_data.fillna('')

# %%
mail_data.loc[mail_data['Category'] == 'spam','Category'] = 0
mail_data.loc[mail_data['Category'] == 'ham','Category'] = 1

# %%
print(mail_data['Category'])
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 5567    0
# 5568    1
# 5569    1
# 5570    1
# 5571    1
# Name: Category, Length: 5572, dtype: object

# %%
x = mail_data['Message']
y = mail_data['Category']

# %%
print(x)
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                 Will ü b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: Message, Length: 5572, dtype: object

# %%
print(y)
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 5567    0
# 5568    1
# 5569    1
# 5570    1
# 5571    1
# Name: Category, Length: 5572, dtype: object

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=3)

# %%
print(x.shape)
print(x_train.shape)
print(x_test.shape)
# Out:
# (5572,)
# (4457,)
# (1115,)

# %%
feature_extraction = TfidfVectorizer(min_df=1,stop_words='english',lowercase=True)
x_feature_train = feature_extraction.fit_transform(x_train)
x_feature_test = feature_extraction.transform(x_test)

y_train = y_train.astype('int')
y_test = y_test.astype('int')

# %%
print(x_feature_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 34775 stored elements and shape (4457, 7431)>
#   Coords	Values
#   (0, 2329)	0.38783870336935383
#   (0, 3811)	0.34780165336891333
#   (0, 2224)	0.413103377943378
#   (0, 4456)	0.4168658090846482
#   (0, 5413)	0.6198254967574347
#   (1, 3811)	0.17419952275504033
#   (1, 3046)	0.2503712792613518
#   (1, 1991)	0.33036995955537024
#   (1, 2956)	0.33036995955537024
#   (1, 2758)	0.3226407885943799
#   (1, 1839)	0.2784903590561455
#   (1, 918)	0.22871581159877646
#   (1, 2746)	0.3398297002864083
#   (1, 2957)	0.3398297002864083
#   (1, 3325)	0.31610586766078863
#   (1, 3185)	0.29694482957694585
#   (1, 4080)	0.18880584110891163
#   (2, 6601)	0.6056811524587518
#   (2, 2404)	0.45287711070606745
#   (2, 3156)	0.4107239318312698
#   (2, 407)	0.509272536051008
#   (3, 7414)	0.8100020912469564
#   (3, 2870)	0.5864269879324768
#   (4, 2870)	0.41872147309323743
#   (4, 487)	0.2899118421746198
#   :	:
#   (4454, 2855)	0.47210665083641806
#   (4454, 2246)	0.47210665083641806
#   (4455, 4456)	0.24920025316220423
#   (4455, 3922)	0.31287563163368587
#   (4455, 6916)	0.19636985317119715
#   (4455, 4715)	0.30714144758811196
#   (4455, 3872)	0.3108911491788658
#   (4455, 7113)	0.30536590342067704
#   (4455, 6091)	0.23103841516927642
#   (4455, 6810)	0.29731757715898277
#   (4455, 5646)	0.33545678464631296
#   (4455, 2469)	0.35441545511837946
#   (4455, 2247)	0.37052851863170466
#   (4456, 2870)	0.31523196273113385
#   (4456, 5778)	0.16243064490100795
#   (4456, 334)	0.2220077711654938
#   (4456, 6307)	0.2752760476857975
#   (4456, 6249)	0.17573831794959716
#   (4456, 7150)	0.3677554681447669
#   (4456, 7154)	0.24083218452280053
#   (4456, 6028)	0.21034888000987115
#   (4456, 5569)	0.4619395404299172
#   (4456, 6311)	0.30133182431707617
#   (4456, 647)	0.30133182431707617
#   (4456, 141)	0.292943737785358

# %%
model = LogisticRegression()

# %%
model.fit(x_feature_train,y_train)
# Out:
# LogisticRegression()

# %%
# prediction on training data

prediction_on_training_data = model.predict(x_feature_train)
accuracy_on_training_data = accuracy_score(y_train, prediction_on_training_data)

# %%
print('Accuracy on training data : ', accuracy_on_training_data)
# Out:
# Accuracy on training data :  0.9676912721561588

# %%
# prediction on training data

prediction_on_test_data = model.predict(x_feature_test)
accuracy_on_test_data = accuracy_score(y_train, prediction_on_training_data)

# %%
print('Accuracy on test data : ', accuracy_on_test_data)
# Out:
# Accuracy on test data :  0.9676912721561588

# %%
train_accuracy = accuracy_score(y_train, prediction_on_training_data)
test_accuracy = accuracy_score(y_test,prediction_on_test_data )

plt.bar(["Train Accuracy", "Test Accuracy"], [train_accuracy, test_accuracy], color=['skyblue','salmon'])
plt.ylim(0,1)  # accuracy is between 0 and 1
plt.ylabel("Accuracy")
plt.title("Model Accuracy")
plt.show()

# %%
# take user input
input_mail = [input("Enter the mail text: ")]

# convert text to feature vectors
input_data_features = feature_extraction.transform(input_mail)

# making prediction
prediction = model.predict(input_data_features)
print("Prediction (0 = Spam, 1 = Ham):", prediction[0])

if prediction[0] == 1:
    print('Ham mail')
else:
    print('Spam mail')
# Out:
# Enter the mail text:  hi hello surprise
# Prediction (0 = Spam, 1 = Ham): 1
# Ham mail
# Prediction (0 = Spam, 1 = Ham): 0
# Spam mail

# %%
import pickle

pickle.dump(model, open("model.pkl", "wb"))
pickle.dump(feature_extraction, open("vectorizer.pkl", "wb"))

# %%
print(model)
# Out:
# LogisticRegression()

# %%
import streamlit as st
import pickle

# Load model and vectorizer
model = pickle.load(open("model.pkl", "rb"))
vectorizer = pickle.load(open("vectorizer.pkl", "rb"))

st.title("📩 Spam Mail Detector")

user_input = st.text_area("Enter your email message:")

if st.button("Check"):
    input_data = vectorizer.transform([user_input])
    prediction = model.predict(input_data)

    if prediction[0] == 1:
        st.success("✅ Ham Mail")
    else:
        st.error("🚨 Spam Mail")
# Out:
# 2026-02-28 10:08:22.096 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.151
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\IRFAN SATHIK ALI\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-02-28 10:08:23.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.157 Session state does not function when running a script without `streamlit run`
# 2026-02-28 10:08:23.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 10:08:23.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
